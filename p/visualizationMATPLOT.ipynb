# %%
 import pandas as pd

# %%
data=pd.read_csv('heart.csv')

# %%
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data=data.drop_duplicates()

# %%
data
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.lineplot(data=data,x=data.age,y=data.cp)
# Out:
# <Axes: xlabel='age', ylabel='cp'>

# %%
sns.lineplot(data=data,x=data.age,y=data.trtbps)
# Out:
# <Axes: xlabel='age', ylabel='trtbps'>

# %%
sns.lineplot(data=data,x=data.age,y=data.chol)
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.lineplot(data=data,x=data.oldpeak,y=data.exng)
# Out:
# <Axes: xlabel='oldpeak', ylabel='exng'>

# %%
sns.histplot(data=data,x=data.output,hue=data.sex)
# Out:
# <Axes: xlabel='output', ylabel='Count'>

# %%
sns.histplot(data=data,x=data.cp,hue=data.sex)
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
sns.histplot(data=data,x=data.cp,hue='output')
# Out:
# <Axes: xlabel='cp', ylabel='Count'>

# %%
temp_data=data[['age','cp','trtbps','chol','fbs','oldpeak','output']]
plt.figure(figsize=(15,10))
sns.pairplot(temp_data,hue="output")
plt.title("Looking for insites of data")
plt.legend("Heart Disease")
plt.tight_layout()
plt.plot()
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
